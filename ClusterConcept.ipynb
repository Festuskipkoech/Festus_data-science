# %% [markdown]
# <a href="https://colab.research.google.com/github/Festuskipkoech/Festus_data-science/blob/main/ClusterConcept.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# genrate synthetic data
# we create datasets with 3 clusters
X, y = make_blobs(n_samples=300, centers=3, random_state=42)

# visualize the raw data
plt.scatter(X[:, 0], X[:, 1], s=50, color='gray', label='Unlabeled Data')

# Step 1: Import Libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs


# Step 2: Generate Synthetic Data

# Creating a dataset with 3 clusters
X, y = make_blobs(n_samples=300, centers=3, random_state=42)


# Step 3: Visualize the Raw Data
plt.scatter(X[:, 0], X[:, 1], s=50, color='gray', label='Unlabeled Data')
plt.title("Unsupervised Learning: Raw Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()


# Step 4: Apply K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)


# Step 5: Visualize the Clusters
plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_, s=50, cmap='viridis', label='Clustered Data')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
plt.title("K-Means Clustering Results")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()
plt.title("Unsupervised learning: Raw data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# apply k-means
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)

# visualize clusters
plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_, s=50, cmap='viridis', label='Clustered Data')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
plt.title("K-Means clustering results")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()
# Out:
# <ipython-input-5-a9ed8be98453>:51: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import pandas

data = pandas.read_csv('data/sales.csv')
data
# Out:
#                               name       sku category  quantity  unit price  \
# 0                      Carroll PLC  QN-82852     Belt        13       44.48
# 1                Heidenreich-Bosco  MJ-21460    Shoes        19       53.62
# 2    Kerluke, Reilly and Bechtelar  AS-93055    Shirt        12       24.16
# 3                    Waters-Walker  AS-93055    Shirt         5       82.68
# 4                    Waelchi-Fahey  AS-93055    Shirt        18       99.64
# ..                             ...       ...      ...       ...         ...
# 995      Kihn, McClure and Denesik  WJ-02096     Belt        11       60.50
# 996                      Kunze Inc  GS-86623    Shoes        16       19.66
# 997                  Waters-Walker  GS-86623    Shoes        13       90.95
# 998                      Huel-Haag  LL-46261    Shoes         9       98.22
# 999              Heidenreich-Bosco  LW-86841    Shoes        14       74.83
#
#      ext price                 date
# ...

# %%
data.isnull().sum()
# Out:
# name          0
# sku           0
# category      0
# quantity      0
# unit price    0
# ext price     0
# date          0
# dtype: int64

# %%
mean=data[['quantity','unit price','ext price']].mean()
mean
# Out:
# quantity       10.32800
# unit price     56.17963
# ext price     579.84390
# dtype: float64

# %%
data[['quantity','unit price','ext price']].max()
# Out:
# quantity        20.00
# unit price      99.97
# ext price     1994.80
# dtype: float64

# %%
data[['quantity','unit price','ext price']].min()
# Out:
# quantity       1.00
# unit price    10.06
# ext price     10.38
# dtype: float64

# %%
data.groupby('category').size()
#data['category'].max()
# Out:
# category
# Belt     196
# Shirt    404
# Shoes    400
# dtype: int64

# %%
import matplotlib as plt
import seaborn as sns

# %%
plt.style.use('seaborn-v0_8')

# %%
sns.countplot(x=data['category'], palette="Blues")
# Out:
# C:\Users\Festus\AppData\Local\Temp\ipykernel_4460\3126885121.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['category'], palette="Blues")
# <Axes: xlabel='category', ylabel='count'>

# %%
colors = ['#3949AB','#2E7D32','#546E7A']

sns.scatterplot(x='unit price', y='ext price', data=data ,palette='Blues',hue='quantity')
# Out:
# <Axes: xlabel='unit price', ylabel='ext price'>

# %%
import numpy

sns.barplot(x='category', y='unit price', data = data, estimator=numpy.mean, palette='Blues', hue='quantity')
# Out:
# <Axes: xlabel='category', ylabel='unit price'>

# %%
sns.swarmplot(x='category', y='ext price',data=data,palette='Blues',hue='quantity')
# Out:
# <Axes: xlabel='category', ylabel='ext price'>

# %%
data.groupby("category").size().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: >

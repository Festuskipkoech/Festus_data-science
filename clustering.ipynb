# %%
import pandas
data = pandas.read_csv('data/Mall_Customers.csv')

data
#pandas is used in the structuring of data and data analysation
# Out:
#      CustomerID  Gender  Age  Annual Income  Spending Score
# 0             1    Male   19           15.0            39.0
# 1             2    Male   21           15.0            81.0
# 2             3  Female   20           16.0             6.0
# 3             4  Female   23           16.0            77.0
# 4             5  Female   31           17.0            40.0
# ..          ...     ...  ...            ...             ...
# 195         196  Female   35          120.0            79.0
# 196         197  Female   45          126.0             NaN
# 197         198    Male   32          126.0            74.0
# 198         199    Male   32          137.0            18.0
# 199         200    Male   30          137.0            83.0
#
# [200 rows x 5 columns]

# %%
data.head(20)
# it prints the first 20 rows
# Out:
#     CustomerID  Gender  Age  Annual Income  Spending Score
# 0            1    Male   19           15.0            39.0
# 1            2    Male   21           15.0            81.0
# 2            3  Female   20           16.0             6.0
# 3            4  Female   23           16.0            77.0
# 4            5  Female   31           17.0            40.0
# 5            6  Female   22           17.0            76.0
# 6            7  Female   35           18.0             6.0
# 7            8  Female   23           18.0            94.0
# 8            9    Male   64           19.0             3.0
# 9           10  Female   30           19.0            72.0
# 10          11    Male   67           19.0            14.0
# 11          12  Female   35           19.0            99.0
# 12          13  Female   58           20.0            15.0
# 13          14  Female   24           20.0            77.0
# 14          15    Male   37           20.0            13.0
# ...

# %%
data.tail(20)
# it prints the last 20 rows
# Out:
#      CustomerID  Gender  Age  Annual Income  Spending Score
# 180         181  Female   37           97.0            32.0
# 181         182  Female   32           97.0            86.0
# 182         183    Male   46           98.0            15.0
# 183         184  Female   29           98.0            88.0
# 184         185     NaN   41           99.0            39.0
# 185         186    Male   30           99.0            97.0
# 186         187  Female   54          101.0            24.0
# 187         188    Male   28            NaN            68.0
# 188         189  Female   41          103.0            17.0
# 189         190  Female   36          103.0            85.0
# 190         191  Female   34          103.0            23.0
# 191         192  Female   32          103.0            69.0
# 192         193    Male   33          113.0             NaN
# 193         194  Female   38          113.0            91.0
# 194         195  Female   47          120.0            16.0
# ...

# %%
import matplotlib as plt
import seaborn as sns
plt.style.use('seaborn-v0_8')
# matplotlib is used for data visualization that is graph plotting whille seaborn is used to make apppear more attractive

# %%
data.groupby('Gender').size().plot(kind='pie', autopct='%1.1f%%')

# groups the data then calculates teh sized of the data then prints out the results
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# CustomerID        0
# Gender            4
# Age               0
# Annual Income     1
# Spending Score    3
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# drops any missing cells and line checks if the dropping has occurred
# Out:
# CustomerID        0
# Gender            0
# Age               0
# Annual Income     0
# Spending Score    0
# dtype: int64

# %%
array = data.values
array
#convertion from a dictionary to a list an array allows input of different data types in this case int and str
# Out:
# array([[1, 'Male', 19, 15.0, 39.0],
#        [2, 'Male', 21, 15.0, 81.0],
#        [3, 'Female', 20, 16.0, 6.0],
#        [4, 'Female', 23, 16.0, 77.0],
#        [5, 'Female', 31, 17.0, 40.0],
#        [6, 'Female', 22, 17.0, 76.0],
#        [7, 'Female', 35, 18.0, 6.0],
#        [8, 'Female', 23, 18.0, 94.0],
#        [9, 'Male', 64, 19.0, 3.0],
#        [10, 'Female', 30, 19.0, 72.0],
#        [11, 'Male', 67, 19.0, 14.0],
#        [12, 'Female', 35, 19.0, 99.0],
#        [13, 'Female', 58, 20.0, 15.0],
#        [14, 'Female', 24, 20.0, 77.0],
#        [15, 'Male', 37, 20.0, 13.0],
#        [16, 'Male', 22, 20.0, 79.0],
#        [17, 'Female', 35, 21.0, 35.0],
#        [18, 'Male', 20, 21.0, 66.0],
#        [19, 'Male', 52, 23.0, 29.0],
#        [20, 'Female', 35, 23.0, 98.0],
#        [21, 'Male', 35, 24.0, 35.0],
#        [22, 'Male', 25, 24.0, 73.0],
#        [23, 'Female', 46, 25.0, 5.0],
#        [24, 'Male', 31, 25.0, 73.0],
#        [25, 'Female', 54, 28.0, 14.0],
# ...

# %%
#:, selects the entire list then we use indexes to elliminate the categorical data type
# 2:5 due to minus 1 rule
# we assign it a variable x because array is a reserved word
x = array[:, 2:5]
x
# Out:
# array([[19, 15.0, 39.0],
#        [21, 15.0, 81.0],
#        [20, 16.0, 6.0],
#        [23, 16.0, 77.0],
#        [31, 17.0, 40.0],
#        [22, 17.0, 76.0],
#        [35, 18.0, 6.0],
#        [23, 18.0, 94.0],
#        [64, 19.0, 3.0],
#        [30, 19.0, 72.0],
#        [67, 19.0, 14.0],
#        [35, 19.0, 99.0],
#        [58, 20.0, 15.0],
#        [24, 20.0, 77.0],
#        [37, 20.0, 13.0],
#        [22, 20.0, 79.0],
#        [35, 21.0, 35.0],
#        [20, 21.0, 66.0],
#        [52, 23.0, 29.0],
#        [35, 23.0, 98.0],
#        [35, 24.0, 35.0],
#        [25, 24.0, 73.0],
#        [46, 25.0, 5.0],
#        [31, 25.0, 73.0],
#        [54, 28.0, 14.0],
#        [29, 28.0, 82.0],
#        [45, 28.0, 32.0],
#        [35, 28.0, 61.0],
#        [40, 29.0, 31.0],
#        [23, 29.0, 87.0],
#        [60, 30.0, 4.0],
#        [21, 30.0, 73.0],
#        [53, 33.0, 4.0],
#        [18, 33.0, 92.0],
#        [49, 33.0, 14.0],
#        [21, 33.0, 81.0],
#        [42, 34.0, 17.0],
# ...

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=10, random_state=42)
# random_state=42 ensures consistency when the code is run a number of times
model.fit(x)
# Out:
# KMeans(n_clusters=10, random_state=42)

# %%
# means = model.cluster_centers_
clusters=pandas.DataFrame(model.cluster_centers_, columns=['age','income', 'score'])
clusters

# gets the mean of the clusters
# Out:
#          age      income      score
# 0  42.384615   47.307692  46.730769
# 1  32.580645   80.451613  82.709677
# 2  43.750000  106.500000  19.875000
# 3  25.272727   25.727273  79.363636
# 4  51.416667   25.166667  11.500000
# 5  25.000000   60.370370  48.777778
# 6  60.206897   55.896552  50.413793
# 7  41.173913   79.130435  15.391304
# 8  32.625000   23.375000  30.500000
# 9  33.833333  117.000000  80.166667

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income  Spending Score
# 0           1    Male   19           15.0            39.0
# 1           2    Male   21           15.0            81.0
# 2           3  Female   20           16.0             6.0
# 3           4  Female   23           16.0            77.0
# 4           5  Female   31           17.0            40.0

# %%
data['cluster']= model.labels_
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income  Spending Score  cluster
# 0           1    Male   19           15.0            39.0        8
# 1           2    Male   21           15.0            81.0        3
# 2           3  Female   20           16.0             6.0        8
# 3           4  Female   23           16.0            77.0        3
# 4           5  Female   31           17.0            40.0        8

# %%
cluster4 = data[data['cluster'] == 4]
cluster4
# Out:
#     CustomerID  Gender  Age  Annual Income  Spending Score  cluster
# 6            7  Female   35           18.0             6.0        4
# 8            9    Male   64           19.0             3.0        4
# 10          11    Male   67           19.0            14.0        4
# 12          13  Female   58           20.0            15.0        4
# 14          15    Male   37           20.0            13.0        4
# 18          19    Male   52           23.0            29.0        4
# 22          23  Female   46           25.0             5.0        4
# 24          25  Female   54           28.0            14.0        4
# 30          31    Male   60           30.0             4.0        4
# 32          33    Male   53           33.0             4.0        4
# 34          35  Female   49           33.0            14.0        4
# 36          37  Female   42           34.0            17.0        4

# %%
cluster4.to_csv('data/cluster4.csv')

# %%
cl4= pandas.read_csv('data/cluster4.csv')
cl4
# Out:
#     Unnamed: 0  CustomerID  Gender  Age  Annual Income  Spending Score  \
# 0            6           7  Female   35           18.0             6.0
# 1            8           9    Male   64           19.0             3.0
# 2           10          11    Male   67           19.0            14.0
# 3           12          13  Female   58           20.0            15.0
# 4           14          15    Male   37           20.0            13.0
# 5           18          19    Male   52           23.0            29.0
# 6           22          23  Female   46           25.0             5.0
# 7           24          25  Female   54           28.0            14.0
# 8           30          31    Male   60           30.0             4.0
# 9           32          33    Male   53           33.0             4.0
# 10          34          35  Female   49           33.0            14.0
# 11          36          37  Female   42           34.0            17.0
#
#     cluster
# 0         4
# 1         4
# ...

# %%
cluster6 = data[data['cluster'] == 6]
cluster6
# Out:
#      CustomerID  Gender  Age  Annual Income  Spending Score  cluster
# 40           41  Female   65           38.0            35.0        6
# 53           54    Male   59           43.0            60.0        6
# 57           58    Male   69           44.0            46.0        6
# 60           61    Male   70           46.0            56.0        6
# 62           63  Female   67           47.0            52.0        6
# 63           64  Female   54           47.0            59.0        6
# 64           65    Male   63           48.0            51.0        6
# 67           68  Female   68           48.0            48.0        6
# 70           71    Male   70           49.0            55.0        6
# 72           73  Female   60           50.0            49.0        6
# 74           75    Male   59           54.0            47.0        6
# 80           81    Male   57           54.0            51.0        6
# 82           83    Male   67           54.0            41.0        6
# ...

# %%
cluster6.to_csv('data/cluster6.csv')

# %%
cluster9 = data[data['cluster'] == 9]
cluster9
# Out:
#      CustomerID  Gender  Age  Annual Income  Spending Score  cluster
# 189         190  Female   36          103.0            85.0        9
# 191         192  Female   32          103.0            69.0        9
# 193         194  Female   38          113.0            91.0        9
# 195         196  Female   35          120.0            79.0        9
# 197         198    Male   32          126.0            74.0        9
# 199         200    Male   30          137.0            83.0        9

# %%
cluster9.to_csv('data/cluster9.csv')

# %%
cluster1= data[data['cluster'] ==1]
cluster1
# Out:
#      CustomerID  Gender  Age  Annual Income  Spending Score  cluster
# 123         124    Male   39           69.0            91.0        1
# 125         126  Female   31           70.0            77.0        1
# 127         128    Male   40           71.0            95.0        1
# 129         130    Male   38           71.0            75.0        1
# 131         132    Male   39           71.0            75.0        1
# 133         134  Female   31           72.0            71.0        1
# 135         136  Female   29           73.0            88.0        1
# 137         138    Male   32           73.0            73.0        1
# 139         140  Female   35           74.0            72.0        1
# 141         142    Male   32           75.0            93.0        1
# 143         144  Female   32           76.0            87.0        1
# 145         146    Male   28           77.0            97.0        1
# 147         148  Female   32           77.0            74.0        1
# ...

# %%
cluster1.to_csv('data/cluster1.csv')

# %%
cluster2 = data[data['cluster']==2]
cluster2
cluster2.to_csv('data/cluster2.csv')

# %%
cluster10 = data[data['cluster']==10]
cluster10
cluster10.to_csv('data/cluster10.csv')

# %%
cluster3 = data[data['cluster']==3]
cluster3
cluster3.to_csv('data/cluster3.csv')

# %%
cl2= pandas.read_csv('data/cluster2.csv')
cl2
# Out:
#    Unnamed: 0  CustomerID  Gender  Age  Annual Income  Spending Score  cluster
# 0         178         179    Male   59           93.0            14.0        2
# 1         180         181  Female   37           97.0            32.0        2
# 2         182         183    Male   46           98.0            15.0        2
# 3         186         187  Female   54          101.0            24.0        2
# 4         188         189  Female   41          103.0            17.0        2
# 5         190         191  Female   34          103.0            23.0        2
# 6         194         195  Female   47          120.0            16.0        2
# 7         198         199    Male   32          137.0            18.0        2

# %%
cluster5 = data[data['cluster']==5]
cluster5
cluster5.to_csv('data/cluster5.csv')

# %%
cluster7 = data[data['cluster']==7]
cluster7
cluster7.to_csv('data/cluster7.csv')

# %%
# cluster8 = data[data['cluster']==8]
# cluster8
# cluster8.to_csv('data/cluster8.csv')

# %%
cluster8 = data[data['cluster']==8]
cluster8
cluster8.to_csv('data/cluster8.csv')

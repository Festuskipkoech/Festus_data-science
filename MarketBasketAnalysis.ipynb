# %% [markdown]
# <a href="https://colab.research.google.com/github/Festuskipkoech/Festus_data-science/blob/main/MarketBasketAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Market Basket Analysis
#
# Market Basket Analysis is a data mining technique used to uncover relationships between items purchased together in a transaction. It helps retailers understand customer purchasing behavior by identifying patterns, such as which products are frequently bought together.

# %% [markdown]
# ## Key Concepts
#
# ### 1. Association Rules
# These are rules that describe the relationships between items. For example, if customers often buy bread and butter together, the rule might be:
# - **If bread is bought, butter is likely to be bought.**

# %% [markdown]
# ### 2. Support
# This measures how often items appear together in transactions. It’s calculated as the proportion of transactions that include both items.

# %% [markdown]
# ### 3. Confidence
# This indicates the likelihood that a customer who buys one item will also buy another. It’s calculated as the support of the item set divided by the support of the first item.

# %% [markdown]
# ### 4. Lift
# This measures the strength of the association between items, comparing the observed support of the items together to the support expected if they were independent. A lift greater than 1 indicates a positive correlation.
#
# ## Applications

# %% [markdown]
# # Market Basket Analysis Uses Apriori Algorithm, which is an Unsupervised Machine Learning
# # Algorithm that is used to associate one item set to another.
#
# #Components of Apriori
# #1. Support
# #2. Confidence
# #3. Lift

# %% [markdown]
# #-- Support
#     #Support refers to the default popularity of any product. You find the support as a quotient of the division of the number of transactions comprising that product
#     #by the total number of transactions. Hence, we get
#     #Support (Biscuits) = (Transactions relating biscuits) / (Total transactions)
#     #= 400/4000 = 10 percent.

# %% [markdown]
# #-- Confidence
#     # Confidence refers to the possibility that the customers bought both biscuits and
#     # chocolates together. So, you need to divide the number of transactions that
#     # comprise both biscuits and chocolates by the total number of biscuit transactions
#     # Confidence = (Transactions relating both biscuits and Chocolate) / (Total
#     # transactions involving Biscuits)
#     # = 200/400
#     # = 50 percent.

# %% [markdown]
# #-- Lift
#     #Consider the above example; lift refers to the increase in the ratio of the sale of chocolates when you sell biscuits.
#     # The mathematical equations of lift are given below.
#     # Lift = (Confidence (Biscuits - chocolates)/ (Support (Biscuits)
#     # = 50/10 = 5
#     # It means that the probability of people buying both biscuits and chocolates together is five times more than that of purchasing the biscuits alone.
#     # If the lift value is below one, it requires that the people

# %%
# MARKET ANALYSIS FOR A SUPERMARKET STORE
# OBJECTIVE: WHICH ITEMS ARE ASSOCIATED TOGETHER TO BOST SALES(LIFT)

# Import the Data Analysis Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the Retail Data
retail_data = pd.read_csv('https://msi.martial.co.ke/data/OnlineRetail.csv')
retail_data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 8  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 9  12/1/2010 8:34       1.69     13047.0  United Kingdom

# %%
# Cusormers were empty
retail_data.isnull().sum()
retail_data.dropna(inplace=True)
retail_data.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
# Lets Check How Many Countries these Business Operates
# You can relate this one to Branches that the Retail Business has.

retail_data.groupby('Country').size().sort_values(ascending=False)# Lets Check How Many Countries these Business Operates
# Out:
# Country
# United Kingdom          361878
# Germany                   9495
# France                    8491
# EIRE                      7485
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               1877
# Portugal                  1480
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# USA                        291
# Israel                     250
# Unspecified                244
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     17
# Saudi Arabia                10
# dtype: int64

# %%
#Lets check for FRANCE
basketdf = (retail_data[retail_data['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

basketdf
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                  0.0                 0.0
# 536852                                  0.0                 0.0
# 536974                                  0.0                 0.0
# 537065                                  0.0                 0.0
# 537463                                  0.0                 0.0
# ...                                     ...                 ...
# C579532                                 0.0                 0.0
# C579562                                 0.0                 0.0
# C580161                                 0.0                 0.0
# C580263                                 0.0                 0.0
# C581316                                 0.0                 0.0
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                                0.0                       0.0
# 536852                                0.0                       0.0
# 536974                                0.0                       0.0
# 537065                                0.0                       0.0
# 537463                                0.0                       0.0
# ...                                   ...                       ...
# C579532                               0.0                       0.0
# C579562                               0.0                       0.0
# C580161                               0.0                       0.0
# C580263                               0.0                       0.0
# C581316                               0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536370                                   24.0                      0.0
# 536852                                    0.0                      0.0
# 536974                                    0.0                      0.0
# 537065                                    0.0                      0.0
# 537463                                    0.0                      0.0
# ...                                       ...                      ...
# C579532                                   0.0                      0.0
# C579562                                   0.0                      0.0
# C580161                                   0.0                      0.0
# C580263                                   0.0                      0.0
# C581316                                   0.0                      0.0
#
# Description   TRELLIS COAT RACK  10 COLOUR SPACEBOY PEN  \
# InvoiceNo
# 536370                      0.0                     0.0
# 536852                      0.0                     0.0
# 536974                      0.0                     0.0
# 537065                      0.0                     0.0
# 537463                      0.0                     0.0
# ...                         ...                     ...
# C579532                     0.0                     0.0
# C579562                     0.0                     0.0
# C580161                     0.0                     0.0
# C580263                     0.0                     0.0
# C581316                     0.0                     0.0
#
# Description  12 COLOURED PARTY BALLOONS  12 EGG HOUSE PAINTED WOOD  ...  \
# InvoiceNo                                                           ...
# 536370                              0.0                        0.0  ...
# 536852                              0.0                        0.0  ...
# 536974                              0.0                        0.0  ...
# 537065                              0.0                        0.0  ...
# 537463                              0.0                        0.0  ...
# ...                                 ...                        ...  ...
# C579532                             0.0                        0.0  ...
# C579562                             0.0                        0.0  ...
# C580161                             0.0                        0.0  ...
# C580263                             0.0                        0.0  ...
# C581316                             0.0                        0.0  ...
#
# Description  WRAP SUKI AND FRIENDS  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo
# 536370                         0.0                          0.0
# 536852                         0.0                          0.0
# 536974                         0.0                          0.0
# 537065                         0.0                          0.0
# 537463                         0.0                          0.0
# ...                            ...                          ...
# C579532                        0.0                          0.0
# C579562                        0.0                          0.0
# C580161                        0.0                          0.0
# C580263                        0.0                          0.0
# C581316                        0.0                          0.0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
# ...                                     ...                              ...
# C579532                                 0.0                              0.0
# C579562                                 0.0                              0.0
# C580161                                 0.0                              0.0
# C580263                                 0.0                              0.0
# C581316                                 0.0                              0.0
#
# Description  ZINC  STAR T-LIGHT HOLDER   ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536370                              0.0                        0.0
# 536852                              0.0                        0.0
# 536974                              0.0                        0.0
# 537065                              0.0                        0.0
# 537463                              0.0                        0.0
# ...                                 ...                        ...
# C579532                             0.0                        0.0
# C579562                             0.0                        0.0
# C580161                             0.0                        0.0
# C580263                             0.0                        0.0
# C581316                             0.0                        0.0
#
# Description  ZINC HERB GARDEN CONTAINER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536370                              0.0                          0.0
# 536852                              0.0                          0.0
# 536974                              0.0                          0.0
# 537065                              0.0                          0.0
# 537463                              0.0                          0.0
# ...                                 ...                          ...
# C579532                             0.0                          0.0
# C579562                             0.0                          0.0
# C580161                             0.0                          0.0
# C580263                             0.0                          0.0
# C581316                             0.0                          0.0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
# ...                                     ...                              ...
# C579532                                 0.0                              0.0
# C579562                                 0.0                              0.0
# C580161                                 0.0                              0.0
# C580263                                 0.0                              0.0
# C581316                                 0.0                              0.0
#
# [458 rows x 1545 columns]

# %%
# One-Hot Encoding
# It replaces any value more than 0 with 1
# Any quantity more than zero(0), will be indicated as 1
import warnings
warnings.filterwarnings('ignore')

def encode_quantities(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basketdf.applymap(encode_quantities)
basket_sets
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                    0                   0
# 536852                                    0                   0
# 536974                                    0                   0
# 537065                                    0                   0
# 537463                                    0                   0
# ...                                     ...                 ...
# C579532                                   0                   0
# C579562                                   0                   0
# C580161                                   0                   0
# C580263                                   0                   0
# C581316                                   0                   0
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                                  0                         0
# 536852                                  0                         0
# 536974                                  0                         0
# 537065                                  0                         0
# 537463                                  0                         0
# ...                                   ...                       ...
# C579532                                 0                         0
# C579562                                 0                         0
# C580161                                 0                         0
# C580263                                 0                         0
# C581316                                 0                         0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536370                                      1                        0
# 536852                                      0                        0
# 536974                                      0                        0
# 537065                                      0                        0
# 537463                                      0                        0
# ...                                       ...                      ...
# C579532                                     0                        0
# C579562                                     0                        0
# C580161                                     0                        0
# C580263                                     0                        0
# C581316                                     0                        0
#
# Description   TRELLIS COAT RACK  10 COLOUR SPACEBOY PEN  \
# InvoiceNo
# 536370                        0                       0
# 536852                        0                       0
# 536974                        0                       0
# 537065                        0                       0
# 537463                        0                       0
# ...                         ...                     ...
# C579532                       0                       0
# C579562                       0                       0
# C580161                       0                       0
# C580263                       0                       0
# C581316                       0                       0
#
# Description  12 COLOURED PARTY BALLOONS  12 EGG HOUSE PAINTED WOOD  ...  \
# InvoiceNo                                                           ...
# 536370                                0                          0  ...
# 536852                                0                          0  ...
# 536974                                0                          0  ...
# 537065                                0                          0  ...
# 537463                                0                          0  ...
# ...                                 ...                        ...  ...
# C579532                               0                          0  ...
# C579562                               0                          0  ...
# C580161                               0                          0  ...
# C580263                               0                          0  ...
# C581316                               0                          0  ...
#
# Description  WRAP SUKI AND FRIENDS  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo
# 536370                           0                            0
# 536852                           0                            0
# 536974                           0                            0
# 537065                           0                            0
# 537463                           0                            0
# ...                            ...                          ...
# C579532                          0                            0
# C579562                          0                            0
# C580161                          0                            0
# C580263                          0                            0
# C581316                          0                            0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                    0                                0
# 536852                                    0                                0
# 536974                                    0                                0
# 537065                                    0                                0
# 537463                                    0                                0
# ...                                     ...                              ...
# C579532                                   0                                0
# C579562                                   0                                0
# C580161                                   0                                0
# C580263                                   0                                0
# C581316                                   0                                0
#
# Description  ZINC  STAR T-LIGHT HOLDER   ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536370                                0                          0
# 536852                                0                          0
# 536974                                0                          0
# 537065                                0                          0
# 537463                                0                          0
# ...                                 ...                        ...
# C579532                               0                          0
# C579562                               0                          0
# C580161                               0                          0
# C580263                               0                          0
# C581316                               0                          0
#
# Description  ZINC HERB GARDEN CONTAINER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536370                                0                            0
# 536852                                0                            0
# 536974                                0                            0
# 537065                                0                            0
# 537463                                0                            0
# ...                                 ...                          ...
# C579532                               0                            0
# C579562                               0                            0
# C580161                               0                            0
# C580263                               0                            0
# C581316                               0                            0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                    0                                0
# 536852                                    0                                0
# 536974                                    0                                0
# 537065                                    0                                0
# 537463                                    0                                0
# ...                                     ...                              ...
# C579532                                   0                                0
# C579562                                   0                                0
# C580161                                   0                                0
# C580263                                   0                                0
# C581316                                   0                                0
#
# [458 rows x 1545 columns]

# %%
# Finally lets apply the Apriori Algorithm
# import association rules and apriori from mlextend library
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# The mostly bought product i.e with higher support
warnings.filterwarnings('ignore')
frequent_itemsets = apriori(basket_sets, min_support=0.1, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.106987                           (LUNCH BAG APPLE DESIGN)
# 1   0.131004                          (LUNCH BAG RED RETROSPOT)
# 2   0.102620                       (LUNCH BAG SPACEBOY DESIGN )
# 3   0.100437                               (LUNCH BAG WOODLAND)
# 4   0.122271                (LUNCH BOX WITH CUTLERY RETROSPOT )
# 5   0.144105                   (PLASTERS IN TIN CIRCUS PARADE )
# 6   0.115721                         (PLASTERS IN TIN SPACEBOY)
# 7   0.146288                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 8   0.655022                                          (POSTAGE)
# 9   0.159389                               (RABBIT NIGHT LIGHT)
# 10  0.117904                         (RED RETROSPOT MINI CASES)
# 11  0.152838                    (RED TOADSTOOL LED NIGHT LIGHT)
# 12  0.106987                         (REGENCY CAKESTAND 3 TIER)
# 13  0.135371              (ROUND SNACK BOXES SET OF4 WOODLAND )
# 14  0.113537              (SET/20 RED RETROSPOT PAPER NAPKINS )
# 15  0.117904                      (SET/6 RED SPOTTY PAPER CUPS)
# 16  0.109170                    (SET/6 RED SPOTTY PAPER PLATES)
# 17  0.106987                              (SPACEBOY LUNCH BOX )
# 18  0.104803                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 19  0.104803                 (LUNCH BAG RED RETROSPOT, POSTAGE)
# 20  0.126638          (PLASTERS IN TIN CIRCUS PARADE , POSTAGE)
# 21  0.117904        (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE)
# 22  0.141921                      (RABBIT NIGHT LIGHT, POSTAGE)
# 23  0.135371           (RED TOADSTOOL LED NIGHT LIGHT, POSTAGE)
# 24  0.126638     (ROUND SNACK BOXES SET OF4 WOODLAND , POSTAGE)
# 25  0.100437             (SET/6 RED SPOTTY PAPER CUPS, POSTAGE)
# 26  0.104803  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...

# %%
# Apply the Association Rules
association_rules(frequent_itemsets, metric="lift", min_threshold=1)
# Out:
#                               antecedents  \
# 0               (LUNCH BAG RED RETROSPOT)
# 1                               (POSTAGE)
# 2        (PLASTERS IN TIN CIRCUS PARADE )
# 3                               (POSTAGE)
# 4      (PLASTERS IN TIN WOODLAND ANIMALS)
# 5                               (POSTAGE)
# 6                    (RABBIT NIGHT LIGHT)
# 7                               (POSTAGE)
# 8         (RED TOADSTOOL LED NIGHT LIGHT)
# 9                               (POSTAGE)
# 10  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 11                              (POSTAGE)
# 12          (SET/6 RED SPOTTY PAPER CUPS)
# 13                              (POSTAGE)
# 14        (SET/6 RED SPOTTY PAPER PLATES)
# 15          (SET/6 RED SPOTTY PAPER CUPS)
#
#                               consequents  antecedent support  \
# 0                               (POSTAGE)            0.131004
# 1               (LUNCH BAG RED RETROSPOT)            0.655022
# 2                               (POSTAGE)            0.144105
# 3        (PLASTERS IN TIN CIRCUS PARADE )            0.655022
# 4                               (POSTAGE)            0.146288
# 5      (PLASTERS IN TIN WOODLAND ANIMALS)            0.655022
# 6                               (POSTAGE)            0.159389
# 7                    (RABBIT NIGHT LIGHT)            0.655022
# 8                               (POSTAGE)            0.152838
# 9         (RED TOADSTOOL LED NIGHT LIGHT)            0.655022
# 10                              (POSTAGE)            0.135371
# 11  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.655022
# 12                              (POSTAGE)            0.117904
# 13          (SET/6 RED SPOTTY PAPER CUPS)            0.655022
# 14          (SET/6 RED SPOTTY PAPER CUPS)            0.109170
# 15        (SET/6 RED SPOTTY PAPER PLATES)            0.117904
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.655022  0.104803    0.800000  1.221333  0.018993    1.724891
# 1             0.131004  0.104803    0.160000  1.221333  0.018993    1.034519
# 2             0.655022  0.126638    0.878788  1.341616  0.032246    2.846070
# 3             0.144105  0.126638    0.193333  1.341616  0.032246    1.061027
# 4             0.655022  0.117904    0.805970  1.230448  0.022082    1.777964
# 5             0.146288  0.117904    0.180000  1.230448  0.022082    1.041112
# 6             0.655022  0.141921    0.890411  1.359361  0.037518    3.147926
# 7             0.159389  0.141921    0.216667  1.359361  0.037518    1.073121
# 8             0.655022  0.135371    0.885714  1.352190  0.035259    3.018559
# 9             0.152838  0.135371    0.206667  1.352190  0.035259    1.067851
# 10            0.655022  0.126638    0.935484  1.428172  0.037966    5.347162
# 11            0.135371  0.126638    0.193333  1.428172  0.037966    1.071854
# 12            0.655022  0.100437    0.851852  1.300494  0.023207    2.328603
# 13            0.117904  0.100437    0.153333  1.300494  0.023207    1.041846
# 14            0.117904  0.104803    0.960000  8.142222  0.091932   22.052402
# 15            0.109170  0.104803    0.888889  8.142222  0.091932    8.017467
#
#     zhangs_metric
# 0        0.208543
# 1        0.525316
# 2        0.297502
# 3        0.738106
# 4        0.219381
# 5        0.542897
# 6        0.314486
# 7        0.766310
# 8        0.307449
# 9        0.755002
# 10       0.346743
# 11       0.869053
# 12       0.261946
# 13       0.669785
# 14       0.984681
# 15       0.994431

# %%
import pandas
data=pandas.read_csv('data/Advertising.csv')
data
# Out:
#       No     TV  Radio  Newspaper  Sales
# 0      1  230.1   37.8       69.2   22.1
# 1      2   44.5   39.3       45.1   10.4
# 2      3   17.2   45.9       69.3    9.3
# 3      4  151.5   41.3       58.5   18.5
# 4      5  180.8   10.8       58.4   12.9
# ..   ...    ...    ...        ...    ...
# 195  196   38.2    3.7       13.8    7.6
# 196  197   94.2    4.9        8.1    9.7
# 197  198  177.0    9.3        6.4   12.8
# 198  199  283.6   42.0       66.2   25.5
# 199  200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# No           0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data.describe()
# Out:
#                No          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
array=data.values
array
# Out:
# array([[  1. , 230.1,  37.8,  69.2,  22.1],
#        [  2. ,  44.5,  39.3,  45.1,  10.4],
#        [  3. ,  17.2,  45.9,  69.3,   9.3],
#        [  4. , 151.5,  41.3,  58.5,  18.5],
#        [  5. , 180.8,  10.8,  58.4,  12.9],
#        [  6. ,   8.7,  48.9,  75. ,   7.2],
#        [  7. ,  57.5,  32.8,  23.5,  11.8],
#        [  8. , 120.2,  19.6,  11.6,  13.2],
#        [  9. ,   8.6,   2.1,   1. ,   4.8],
#        [ 10. , 199.8,   2.6,  21.2,  10.6],
#        [ 11. ,  66.1,   5.8,  24.2,   8.6],
#        [ 12. , 214.7,  24. ,   4. ,  17.4],
#        [ 13. ,  23.8,  35.1,  65.9,   9.2],
#        [ 14. ,  97.5,   7.6,   7.2,   9.7],
#        [ 15. , 204.1,  32.9,  46. ,  19. ],
#        [ 16. , 195.4,  47.7,  52.9,  22.4],
#        [ 17. ,  67.8,  36.6, 114. ,  12.5],
#        [ 18. , 281.4,  39.6,  55.8,  24.4],
#        [ 19. ,  69.2,  20.5,  18.3,  11.3],
#        [ 20. , 147.3,  23.9,  19.1,  14.6],
#        [ 21. , 218.4,  27.7,  53.4,  18. ],
# ...

# %%
x=array[:, 1:4]

# %%
y=array[:, 4]

# %%
from sklearn import model_selection
x_train,x_test,y_train,x_test=model_selection.train_test_split(x,y, test_size=0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

# %%
models =[]
models.append(('d trees',DecisionTreeRegressor()))
models.append(('knc',KNeighborsRegressor() ))
models.append(('random forest',RandomForestRegressor() ))
models.append(('gradient',GradientBoostingRegressor() ))
models.append(('svr',SVR(gamma='auto') ))

# %%
from sklearn.model_selection import cross_val_score, KFold

for name, model in models:
    kfold = KFold(n_splits=10, random_state=42, shuffle=True)
    cv_results = cross_val_score(model, x_train, y_train, cv=kfold, scoring='r2')

    print(name, 'Results=' , cv_results.mean())
# Out:
# d trees Results= 0.908742893688909
# knc Results= 0.8790725161630053
# random forest Results= 0.9668104456823837
# gradient Results= 0.9667524602265486
# svr Results= -0.1642233881346364

# %%
model1=DecisionTreeRegressor()
model1.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
budjet=[[100,100,23]]
sales=model1.predict(budjet)
print(sales)
# Out:
# [14.7]

# %%
prediction1=model1.predict(x_test)
print('Model1 predicted', prediction1)
print('We expected our', y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 prediction1=model1.predict(x_test)
#       2 print('Model1 predicted', prediction1)
#       3 print('We expected our', y_test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\tree\_classes.py:529, in BaseDecisionTree.predict(self, X, check_input)
#     506 """Predict class or regression value for X.
#     507
#     508 For a classification model, the predicted class for each sample in X is
#    (...)
#     526     The predicted classes, or the predict values.
#     527 """
#     528 check_is_fitted(self)
# --> 529 X = self._validate_X_predict(X, check_input)
#     530 proba = self.tree_.predict(X)
#     531 n_samples = X.shape[0]
#
# ...
